# %%
import pandas as pd
import numpy as np
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

# %%
##Client Authorization

cid = "26e46f3a7818494286f6349bd492484d"
secret = "f96866fd97af42b38349b865821e631f"
ruri = "http://localhost:64664/callback"

scope = "user-library-read"

client_credentials_manager = SpotifyClientCredentials(client_id=cid, client_secret = secret)
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(scope=scope, client_id = cid, client_secret = secret, redirect_uri = ruri))

# %%
##function to add tracks to a dataframe
def track_adder(dataframe, track_dict): ##where dataframe is the master dataframe and track_dict a dictionary with structure {playlist title: [uri, mood]}
    for playlist in track_dict:
        plist = sp.playlist_tracks(track_dict[playlist][0]) ##gets the json entry for the playlist from the api
        i = 0
        while i < len(plist["items"]): ##crawl through the tracks in items
            dataframe = dataframe.append({"track": plist["items"][i]["track"]["name"], "uri": plist["items"][i]["track"]["uri"], "mood": track_dict[playlist][1]}, ignore_index = True) ##adds each track info to the dataframe
            i = i+1
    return dataframe

# %%
##function to add track features to data frame
def feature_adder(dataframe): ##just needs a data frame 
    for index, row in dataframe.iterrows():
        features = sp.audio_features(row[1]) ##pulls the audio features and fills them in accordingly
        row[3] = features[0]["danceability"]
        row[4] = features[0]["energy"]
        row[5] = features[0]["key"]
        row[6] = features[0]["loudness"]
        row[7] = features[0]["mode"]
        row[8] = features[0]["speechiness"]
        row[9] = features[0]["acousticness"]
        row[10] = features[0]["instrumentalness"]
        row[11] = features[0]["liveness"]
        row[12] = features[0]["valence"]
        row[13] = features[0]["tempo"]
    return dataframe

# %%
##function to create our database
def create_database(trackDict): ##track_dict a dictionary with structure {playlist title: [uri, mood]}
    tracks = pd.DataFrame(columns = ["track", "uri", "mood", "danceability", "energy", "key","loudness", "mode", "speechiness", "acousticness", "instrumentalness", "liveness", "valence", "tempo"], index = None)
    tracks = track_adder(tracks, trackDict)
    tracks = feature_adder(tracks)
    return tracks

# %%
##testing all the functions
## testing track_dict
testing = {"happy": ["spotify:playlist:574pNsFHHsY8Dp12ppLiim", "happy"], "sad": ["spotify:playlist:4po6P93XjiQ3CC3UB9UlWV", "sad"]}
create_database(testing)
# Out:
#                               track                                   uri  \
# 0                     Electric Love  spotify:track:2GiJYvgVaD2HtM8GqD9EgQ
# 1                        SUPERBLOOM  spotify:track:2HvtedoEeymVWrBPyAMNwZ
# 2  Let's Fall in Love for the Night  spotify:track:7kQkmyoHCEqwe7QwDbkSXM
# 3           The Bones - with Hozier  spotify:track:1yTTMcUhL7rtz08Dsgb7Qb
# 4                   Black And White  spotify:track:7rpNuuoMbid56XkDsx2FjE
# 5                       Oil & Water  spotify:track:4HwJ2gvewwzC3NsC9WwmlA
# 6                            Coping  spotify:track:0RjKWagIjeOoxpsiCT4gls
# 7                           Routine  spotify:track:5oRAL1SuCwcdDx6IwK54kL
# 8                           For Now  spotify:track:5wV2TAUTKHcKgaEB6XnWDI
# 9     Swollen (feat. Julia Gargano)  spotify:track:1XZG6gPL5pKw7MLRXCK1yX
#
#     mood danceability energy key loudness mode speechiness acousticness  \
# 0  happy        0.611  0.797   6   -7.627    0      0.0533      0.00543
# 1  happy        0.558  0.889   8   -3.945    1       0.102        0.191
# 2  happy        0.737  0.408   5   -7.941    1       0.104        0.802
# 3  happy        0.561  0.597  11       -6    0      0.0405        0.286
# 4  happy        0.443  0.582   2    -6.02    1      0.0482       0.0301
# 5    sad        0.577  0.377  10   -6.669    1      0.0325        0.699
# 6    sad        0.502  0.444   6   -7.294    1       0.116        0.613
# 7    sad        0.641  0.249   4  -13.669    1      0.0733        0.748
# 8    sad        0.731  0.233   1  -11.109    1      0.0376         0.89
# 9    sad        0.447  0.376  10   -9.262    1      0.0316        0.837
#
#   instrumentalness liveness valence    tempo
# 0          0.00137     0.26   0.518  120.041
# 1         0.000387    0.328   0.716  170.102
# 2                0    0.171   0.374  127.921
# 3                0   0.0979   0.355   76.826
# 4                0    0.127   0.239  147.589
# 5                0    0.128   0.238  126.368
# 6                0    0.103   0.196  157.604
# 7                0    0.316   0.109   85.998
# 8                0      0.3   0.408  108.008
# 9         0.000222    0.116   0.219  140.757

# %%
playlistData = {"mood booster": ["spotify:playlist:37i9dQZF1DX3rxVfibe1L0", "happy"], "have a great day": ["spotify:playlist:37i9dQZF1DX7KNKjOK0o75", "happy"], "happy hits": ["spotify:playlist:37i9dQZF1DXdPec7aLTmlC", "happy"], "buenas vibras": ["spotify:playlist:37i9dQZF1DX3NRlBOcUOcY", "happy"], "beast mode": ["spotify:playlist:37i9dQZF1DX76Wlfdnj7AP", "hype"], "all the feels": ["spotify:playlist:37i9dQZF1DX7gIoKXt0gmx", "sad"], "tear drop": ["spotify:playlist:37i9dQZF1DX6xZZEgC9Ubl", "sad"], "down in the dumps": ["spotify:playlist:37i9dQZF1DWSqBruwoIXkA", "sad"], "sad songs": ["spotify:playlist:37i9dQZF1DX7qK8ma5wgG1", "sad"], "feelin' myself": ["spotify:playlist:37i9dQZF1DX6GwdWRQMQpq", "hype"], "hype": ["spotify:playlist:37i9dQZF1DX4eRPd9frC1m", "hype"], "chilled r and b": ["spotify:playlist:37i9dQZF1DX2UgsUIg75Vg", "relaxed"], "stay in bed": ["spotify:playlist:37i9dQZF1DX6tTW0xDxScH", "relaxed"], "afternoon acoustic": ["spotify:playlist:37i9dQZF1DX4E3UdUs7fUx", "relaxed"], "sunday stroll": ["spotify:playlist:37i9dQZF1DWSSBwgXMlrMk", "relaxed"]}

# %%
tracksData = create_database(playlistData)

# %%
print(tracksData)
# Out:
#                                                   track  \
# 0                                         Electric Love
# 1                                            SUPERBLOOM
# 2                      Let's Fall in Love for the Night
# 3                               The Bones - with Hozier
# 4     Edge of Midnight (Midnight Sky Remix) (feat. S...
# 5                                       Black And White
# 6                 Stay Next To Me (with Chelsea Cutler)
# 7                                                 Bang!
# 8                                             survivin'
# 9                                   Put Your Records On
# 10                                          Free Spirit
# 11                                            Adore You
# 12                   Blueberry Eyes (feat. SUGA of BTS)
# 13                                         Take It Easy
# 14                    You (with Marshmello & Vance Joy)
# 15                                             Your Man
